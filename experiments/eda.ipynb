# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/comments.csv')

# %%
df.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  VmeH2OFfxOi-kRbagLX2RITw6w4
# 1  youtube#commentThread  4vRHR9-fWgxnqGcw2gFgJ6tjGoY
# 2  youtube#commentThread  xKiC8_Mf7x9l0Ar9vw8TYQI4yns
# 3  youtube#commentThread  LXMTK-F_v0V334Y-L-1Rlb4_6Bc
# 4  youtube#commentThread  0xd-MzwAtA9FtS4bbp0c4PLbR-I
#
#                            id         snippet.channelId snippet.videoId  \
# 0  UgxAFra4n3hDQBuXRzd4AaABAg  UC-lHJZR3Gqxm24_Vd_AJ5Yw     iRRpvuMG7AM
# 1  Ugz4MyivMAIdH18BGzB4AaABAg  UC-lHJZR3Gqxm24_Vd_AJ5Yw     iRRpvuMG7AM
# 2  Ugzwwm2KZyWKg-qrfp14AaABAg  UC-lHJZR3Gqxm24_Vd_AJ5Yw     iRRpvuMG7AM
# 3  UgzjWdJstPSbdSgSceZ4AaABAg  UC-lHJZR3Gqxm24_Vd_AJ5Yw     iRRpvuMG7AM
# 4  UgwSPqrbnXn8bnyiCaV4AaABAg  UC-lHJZR3Gqxm24_Vd_AJ5Yw     iRRpvuMG7AM
#
#   snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 0              youtube#comment  4mMoJa-Cu039VafuRtxoiUFr4fA
# 1              youtube#comment  0JhJ0ohwEfbKv1SKxjZTr6_gx3M
# 2              youtube#comment  MWuyzNlnTpZf14IBKHb5UffdqCE
# 3              youtube#comment  rLKyCpFiUfrtG9sfKMUMVBmxevQ
# 4              youtube#comment  aqrC52TbqhX9m4c1mhy8w8UbnEw
#
#    snippet.topLevelComment.id snippet.topLevelComment.snippet.channelId  \
# 0  UgxAFra4n3hDQBuXRzd4AaABAg                  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 1  Ugz4MyivMAIdH18BGzB4AaABAg                  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 2  Ugzwwm2KZyWKg-qrfp14AaABAg                  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 3  UgzjWdJstPSbdSgSceZ4AaABAg                  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 4  UgwSPqrbnXn8bnyiCaV4AaABAg                  UC-lHJZR3Gqxm24_Vd_AJ5Yw
#
#   snippet.topLevelComment.snippet.videoId  ...  \
# 0                             iRRpvuMG7AM  ...
# 1                             iRRpvuMG7AM  ...
# 2                             iRRpvuMG7AM  ...
# 3                             iRRpvuMG7AM  ...
# 4                             iRRpvuMG7AM  ...
#
#   snippet.topLevelComment.snippet.authorChannelUrl  \
# 0                   http://www.youtube.com/@26days
# 1          http://www.youtube.com/@scitechaiutopia
# 2            http://www.youtube.com/@natenoisy7571
# 3                 http://www.youtube.com/@CptSauce
# 4                http://www.youtube.com/@sean89999
#
#   snippet.topLevelComment.snippet.authorChannelId.value  \
# 0                           UCYYD2_8nP2Ym7DmGPZKCxqw
# 1                           UCS8AXA5NveSRpMu9fbohijA
# 2                           UCtx6BYDRmttb2-OxC8HqzAQ
# 3                           UCfkYpm5tznz6K5wzF-f5StA
# 4                           UC1YpAmcJTlgIk0Oho6maEwQ
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   snippet.topLevelComment.snippet.viewerRating  \
# 0                                         none
# 1                                         none
# 2                                         none
# 3                                         none
# 4                                         none
#
#   snippet.topLevelComment.snippet.likeCount  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                        2026-06-29T09:53:46Z
# 1                        2026-06-29T09:51:30Z
# 2                        2026-06-29T09:43:07Z
# 3                        2026-06-29T09:33:24Z
# 4                        2026-06-29T09:11:08Z
#
#    snippet.topLevelComment.snippet.updatedAt snippet.canReply  \
# 0                       2026-06-29T09:53:46Z             True
# 1                       2026-06-29T09:51:30Z             True
# 2                       2026-06-29T09:43:07Z             True
# 3                       2026-06-29T09:33:24Z             True
# 4                       2026-06-29T09:11:08Z             True
#
#    snippet.totalReplyCount snippet.isPublic
# 0                        0             True
# 1                        0             True
# 2                        0             True
# 3                        0             True
# 4                        0             True
#
# [5 rows x 24 columns]

# %%
isnull = df.isnull().sum()
print(isnull)
# Out:
# kind                                                     0
# etag                                                     0
# id                                                       0
# snippet.channelId                                        0
# snippet.videoId                                          0
# snippet.topLevelComment.kind                             0
# snippet.topLevelComment.etag                             0
# snippet.topLevelComment.id                               0
# snippet.topLevelComment.snippet.channelId                0
# snippet.topLevelComment.snippet.videoId                  0
# snippet.topLevelComment.snippet.textDisplay              0
# snippet.topLevelComment.snippet.textOriginal             0
# snippet.topLevelComment.snippet.authorDisplayName        0
# snippet.topLevelComment.snippet.authorProfileImageUrl    0
# snippet.topLevelComment.snippet.authorChannelUrl         0
# snippet.topLevelComment.snippet.authorChannelId.value    0
# snippet.topLevelComment.snippet.canRate                  0
# snippet.topLevelComment.snippet.viewerRating             0
# snippet.topLevelComment.snippet.likeCount                0
# snippet.topLevelComment.snippet.publishedAt              0
# snippet.topLevelComment.snippet.updatedAt                0
# snippet.canReply                                         0
# snippet.totalReplyCount                                  0
# snippet.isPublic                                         0
# dtype: int64

# %%
for column in df.columns:
    print(column)
# Out:
# kind
# etag
# id
# snippet

# %%
df['snippet.topLevelComment.snippet.textDisplay']
# Out:
# 0                      the tigers are drawn so well wtf
# 1     I would rather create tens of thousands of dre...
# 2                                   damn he worked hard
# 3                                            Id buy it.
# 4                          Never like a video that fast
#                             ...
# 95    me gusta mucho que hacemos los mismos efectos ...
# 96    Despite the boy having no face but I can feel ...
# 97    The pages struggle is like when I wrote a poem...
# 98                                                Nooo😢
# 99    He&#39;s just enjoying his life doing side que...
# Name: snippet.topLevelComment.snippet.textDisplay, Length: 100, dtype: str
